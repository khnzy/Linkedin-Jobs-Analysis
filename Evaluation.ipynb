# %% [markdown]
# # Evaluation Portfolio ( Task-3 )

# %% [markdown]
# ## Step 1 - Loading Dataset

# %%
# Importing all necessary librarires required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Loading data from Local Storage

data = pd.read_excel("linkdin_Job_data.xlsx")
data.head(5)
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         NaN                 Crossover
# 1         New Delhi, Delhi, India         NaN                 Crossover
# 2          Greater Bengaluru Area         NaN                    Uplers
# 3        Gurugram, Haryana, India         NaN             PVAR SERVICES
# 4  Mohali district, Punjab, India         NaN  Timeline Freight Brokers
#
#   work_type              full_time_remote  \
# 0    Remote         Full-time · Associate
# 1    Remote         Full-time · Associate
# ...

# %%
# Check complete data size
data.shape
# Out:
# (7927, 15)

# %%
# Checking for column names
data.columns
# Out:
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'alumni', 'Hiring_person', 'linkedin_followers',
#        'hiring_person_link', 'job_details'],
#       dtype='object')

# %%
# checking for datatypes
data.dtypes.reset_index()
# Out:
#                  index        0
# 0               job_ID    int64
# 1                  job   object
# 2             location   object
# 3           company_id  float64
# 4         company_name   object
# 5            work_type   object
# 6     full_time_remote   object
# 7         no_of_employ   object
# 8    no_of_application   object
# 9       posted_day_ago   object
# 10              alumni   object
# 11       Hiring_person   object
# 12  linkedin_followers   object
# 13  hiring_person_link   object
# 14         job_details   object

# %%
# Checking data description
data.describe()
# Out:
#              job_ID  company_id
# count  7.927000e+03         0.0
# mean   3.466724e+09         NaN
# std    5.778011e+07         NaN
# min    1.419216e+08         NaN
# 25%    3.467367e+09         NaN
# 50%    3.471882e+09         NaN
# 75%    3.476181e+09         NaN
# max    3.477823e+09         NaN

# %%
# Index(['job_ID', 'job', 'location', 'company_id', 'company_name', 'work_type',
#        'full_time_remote', 'no_of_employ', 'no_of_application',
#        'posted_day_ago', 'alumni', 'Hiring_person', 'linkedin_followers',
#        'hiring_person_link', 'job_details'],
#       dtype='object')

data.duplicated().value_counts()
# Out:
# False    7848
# True       79
# Name: count, dtype: int64

# %%
# checking for null values
data.isnull().sum().reset_index()
# Out:
#                  index     0
# 0               job_ID     0
# 1                  job    33
# 2             location    33
# 3           company_id  7927
# 4         company_name    35
# 5            work_type   191
# 6     full_time_remote    79
# 7         no_of_employ   324
# 8    no_of_application    40
# 9       posted_day_ago     7
# 10              alumni  3069
# 11       Hiring_person  2207
# 12  linkedin_followers  3113
# 13  hiring_person_link  2207
# 14         job_details    46

# %%
# Checking null values in terms of percentage
data.isnull().sum()/100
# Out:
# job_ID                 0.00
# job                    0.33
# location               0.33
# company_id            79.27
# company_name           0.35
# work_type              1.91
# full_time_remote       0.79
# no_of_employ           3.24
# no_of_application      0.40
# posted_day_ago         0.07
# alumni                30.69
# Hiring_person         22.07
# linkedin_followers    31.13
# hiring_person_link    22.07
# job_details            0.46
# dtype: float64

# %%
null_percent = data.isnull().sum()/data.shape[0]*100
null_percent.reset_index()
# Out:
#                  index           0
# 0               job_ID    0.000000
# 1                  job    0.416299
# 2             location    0.416299
# 3           company_id  100.000000
# 4         company_name    0.441529
# 5            work_type    2.409487
# 6     full_time_remote    0.996594
# 7         no_of_employ    4.087297
# 8    no_of_application    0.504605
# 9       posted_day_ago    0.088306
# 10              alumni   38.715782
# 11       Hiring_person   27.841554
# 12  linkedin_followers   39.270846
# 13  hiring_person_link   27.841554
# 14         job_details    0.580295

# %%
job = data["job"].reset_index()
job.value_counts()
# Out:
# index  job
# 0      Data Analyst, Trilogy (Remote) - $60,000/year USD    1
# 5291   Senior Data Quality Engineer                         1
# 5289   Senior Automation Tester                             1
# 5288   Web Designer                                         1
# 5287   Senior Automation Tester                             1
#                                                            ..
# 2634   Executive Assistant                                  1
# 2633   IMS Engineer                                         1
# 2632   PL/SQL Developer                                     1
# 2631   Snowflake Developers/Lead                            1
# 7926   Power train function developer                       1
# Name: count, Length: 7894, dtype: int64

# %%
data["job"].head(30).reset_index()
# Out:
#     index                                                job
# 0       0  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1       1  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2       2                                 Data Analyst - WFH
# 3       3                                       Data Analyst
# 4       4                                       Data Analyst
# 5       5                                       Data Analyst
# 6       6  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 7       7                                  Shopify Developer
# 8       8                                 Database Developer
# 9       9                                  Shopify Developer
# 10     10                                  Shopify Developer
# 11     11                                      Data Engineer
# 12     12                                      Tableau (APL)
# 13     13                             Data Engineer (Python)
# ...

# %%
data.sample(frac=0.1)
# Out:
#           job_ID                                                job  \
# 3136  3476293212                                Lead Java Developer
# 7354  3464550932                                    Account Manager
# 7298  3474929196  VP / AVP – Financial Research (Remote Working ...
# 6286  3469295727                                            Doorman
# 3357  3476299075                        Lead Java Software Engineer
# ...          ...                                                ...
# 2466  3465478600                               Sr. Business Analyst
# 5428  3476296236                           Senior Automation Tester
# 3545  3476290736                        Lead Java Software Engineer
# 5184  3476290282                           Senior Automation Tester
# 5084  3476400678                Lead Automation Tester (JavaScript)
#
#                                   location  company_id  \
# 3136           Bengaluru, Karnataka, India         NaN
# ...

# %%
data.job
# Out:
# 0       Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1       Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2                                      Data Analyst - WFH
# 3                                            Data Analyst
# 4                                            Data Analyst
#                               ...
# 7922                                   Back End Developer
# 7923                           Software Engineer - Senior
# 7924                                               Vue JS
# 7925                                        iOS Developer
# 7926                       Power train function developer
# Name: job, Length: 7927, dtype: object

# %%
plt.figure(figsize=(20,10))
# sns.barplot(null_percent)

plt.bar(null_percent["index"],null_percent[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/udemy/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 4
#       1 plt.figure(figsize=(20,10))
# ...

# %% [markdown]
# ## Step 2 - Data Cleaning

# %% [markdown]
# ## Step 3 - Data Transformation

# %% [markdown]
# ## Step 4 - Data Visualisation
